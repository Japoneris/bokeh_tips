# %%
import psutil

# %%
psutil.sensors_temperatures()
# Out:
# {'acpitz': [shwtemp(label='', current=25.0, high=107.0, critical=107.0)],
#  'pch_cannonlake': [shwtemp(label='', current=54.0, high=None, critical=None)],
#  'coretemp': [shwtemp(label='Package id 0', current=62.0, high=100.0, critical=100.0),
#   shwtemp(label='Core 0', current=60.0, high=100.0, critical=100.0),
#   shwtemp(label='Core 1', current=61.0, high=100.0, critical=100.0),
#   shwtemp(label='Core 2', current=61.0, high=100.0, critical=100.0),
#   shwtemp(label='Core 3', current=61.0, high=100.0, critical=100.0),
#   shwtemp(label='Core 4', current=61.0, high=100.0, critical=100.0),
#   shwtemp(label='Core 5', current=59.0, high=100.0, critical=100.0)],
#  'iwlwifi_1': [shwtemp(label='', current=41.0, high=None, critical=None)]}

# %%
dico = psutil.sensors_fans()

for v, rows in dico.items():
    print(v)
    for val in rows:
        print(val.label, val.current)
# Out:
# dell_smm
#  4902
#  4902

# %%
psutil.cpu_percent()
# Out:
# 10.4

# %%
psutil.cpu_times()
# Out:
# scputimes(user=140515.75, nice=26.8, system=39944.55, idle=397068.57, iowait=1018.96, irq=0.0, softirq=917.27, steal=0.0, guest=0.0, guest_nice=0.0)

# %%
psutil.disk_io_counters()
# Out:
# sdiskio(read_count=1590570, write_count=2593029, read_bytes=18358893056, write_bytes=51455012864, read_time=931136, write_time=37433272, read_merged_count=0, write_merged_count=2581754, busy_time=2744280)

# %%
psutil.net_io_counters()
# Out:
# snetio(bytes_sent=2246676662, bytes_recv=9851904122, packets_sent=2676037, packets_recv=7724572, errin=0, errout=0, dropin=0, dropout=0)
